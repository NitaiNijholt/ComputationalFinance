# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# # Plotting Pay-off functions of options

# %%
# Params
strike_price = 50
premium_call = 0
premium_put = 0
stock_prices = np.linspace(30,70,100)

# Calculate payoffs

# Note when we go long we pay the premium
payoff_long_call = np.maximum(0, stock_prices - strike_price) - premium_call
payoff_long_put = np.maximum(0, strike_price - stock_prices) - premium_put
# When we go short we receive the premium
payoff_short_call = -np.maximum(0,stock_prices - strike_price) + premium_call
payoff_short_put = -np.maximum(0, strike_price - stock_prices) + premium_put
bond_payoff_value = strike_price

# Plotting
plt.figure(figsize=(14,7))

# Payoff diagrams:

# Long Call
plt.subplot(3, 2, 1)
plt.plot(stock_prices, payoff_long_call, color='blue', label='Long Call Payoff')
plt.axhline(0, color='black', lw=1)
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Long Call Option Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.legend()
plt.grid(True)

# Long Put
plt.subplot(3, 2, 2)
plt.plot(stock_prices, payoff_long_put, color='blue', label='Long Put Payoff')
plt.axhline(0, color='black', lw=1)
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Long Put Option Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.legend()
plt.grid(True)

# Short Call
plt.subplot(3, 2, 3)
plt.plot(stock_prices, payoff_short_call, color='blue', label='Short Call Payoff')
plt.axhline(0, color='black', lw=1)
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Short Call Option Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.legend()
plt.grid(True)

# Short Put 
plt.subplot(3, 2, 4)
plt.plot(stock_prices, payoff_short_put, color='blue', label='Short Put Payoff')
plt.axhline(0, color='black', lw=1)
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Short Put Option Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.legend()
plt.grid(True)

# Payoff stock
plt.subplot(3, 2, 5)
plt.plot(stock_prices, stock_prices - strike_price, color='blue', label='Stock Payoff')
plt.axhline(0, color='black', lw=1)
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Stock Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.legend()
plt.grid(True)

# Payoff bonds
plt.subplot(3, 2, 6)
plt.axhline(bond_payoff_value, color='blue', linestyle='-', lw=1, label='Bond Payoff')
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Bond Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Part A

# %% [markdown]
#  ### 1.4

# %% [markdown]
# Constructing the payoff diagrams for 2 portfolios:
#
# Portfolio 1: $C_{t} + Ke^{-rT}$
#
# Portfolio 2: $P_{t} + S$

# %%
plt.figure(figsize=(14,7))

# Portfolio 1: Plotting the stock price against payoff of C_{t} and Ke^{rT}
plt.subplot(1, 2, 1)

plt.plot(stock_prices, payoff_long_call + bond_payoff_value, color='blue', label='Long Call + Bond Payoff')
plt.axhline(0, color='black', lw=1)
plt.axhline(bond_payoff_value, color='purple', lw=1, label ='Long Bond', linestyle = '--')
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Stock Price ($K$) at Expiration ($T$)')
plt.title('Portfolio 1: $C_{t}$ + $Ke^{rT}$ Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
# Adjusting legend position
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=2)
plt.ylim(-20,80)
plt.xlim(30,70)
plt.grid(True)

# Portfolio 2: Plotting the stock price against payoff of P_{t} and S
plt.subplot(1, 2, 2)
plt.plot(stock_prices, stock_prices, color='orange', label='Stock Payoff', linestyle='--')
plt.plot(stock_prices, payoff_long_put, color='green', label='Long Put Payoff', linestyle='--')
plt.plot(stock_prices, payoff_long_put + stock_prices, color='blue', label='Long Put + Stock Payoff')
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Stock Price ($K$) at Expiration ($T$)')
plt.axhline(0, color='black', lw=1)
plt.title('Portfolio 2: $P_{t}$ + $S$ Payoff')
plt.xlabel('Stock Price $K$ at Expiration')
plt.ylabel('Payoff')
# Adjusting legend position
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=2)
plt.ylim(-20,80)
plt.xlim(30,70)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(21,14))
# Long Call
plt.subplot(3, 2, 3)
plt.plot(stock_prices, payoff_long_call, color='blue', label='Long Call Payoff')
plt.axhline(0, color='black', lw=1)
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Long Call Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.ylim(-20,80)
plt.xlim(30,70)
plt.legend()
plt.grid(True)

# Bond
plt.subplot(3, 2, 1)
plt.axhline(bond_payoff_value, color='purple', lw=1, label ='Bond Payoff')
plt.axhline(0, color='black', lw=1)
plt.title('Bond Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylim(-20,80)
plt.xlim(30,70)
plt.legend()
plt.grid(True)

# Stock
plt.subplot(3, 2, 2)
plt.plot(stock_prices, stock_prices, color='orange', label='Stock Payoff')
plt.axhline(0, color='black', lw=1)
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Stock Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.ylim(-20,80)
plt.xlim(30,70)
plt.legend()
plt.grid(True)

# Long Put
plt.subplot(3, 2, 4)
plt.plot(stock_prices, payoff_long_put, color='green', label='Long Put Payoff')
plt.axhline(0, color='black', lw=1)
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Strike Price')
plt.title('Long Put Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.ylim(-20,80)
plt.xlim(30,70)
plt.legend()
plt.grid(True)

# Portfolio 1: Long Call + Bond
plt.subplot(3, 2, 5)
plt.plot(stock_prices, payoff_long_call + bond_payoff_value, color='blue', label='Long Call + Bond Payoff')
plt.axhline(0, color='black', lw=1)
plt.axhline(bond_payoff_value, color='purple', lw=1, label ='Long Bond', linestyle = '--')
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Stock Price at Expiration')
plt.title('Portfolio 1: $C_{t}$ + $Ke^{rT}$ Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.ylim(-20,80)
plt.xlim(30,70)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=2)
plt.grid(True)

# Portfolio 2: Long Put + Stock
plt.subplot(3, 2, 6)
plt.plot(stock_prices, stock_prices, color='orange', label='Stock Payoff', linestyle='--')
plt.plot(stock_prices, payoff_long_put, color='green', label='Long Put Payoff', linestyle='--')
plt.plot(stock_prices, payoff_long_put + stock_prices, color='blue', label='Long Put + Stock Payoff')
plt.axvline(strike_price, color='red', linestyle='--', lw=1, label='Stock Price at Expiration')
plt.axhline(0, color='black', lw=1)
plt.title('Portfolio 2: $P_{t}$ + $S$ Payoff')
plt.xlabel('Stock Price at Expiration')
plt.ylabel('Payoff')
plt.ylim(-20,80)
plt.xlim(30,70)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=2)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Part B

# %%
def buildTree(S, vol, T, N):
    dt = T/N

    matrix = np.zeros((N+1, N+1))

    u = np.exp(vol*np.sqrt(dt))
    d = np.exp(-vol*np.sqrt(dt))
    
    # Set stock price to be the first element
    matrix[0,0] = S

    # Iterate over the lower triangle, at this point first element still get erased, need to fix
    for i in np.arange(N + 1): # iterate over rows
        for j in np.arange(i + 1): # iterate over the columns

                # Hint: express each cell as a combination of up and down moves
                matrix[i,j] = S * u**j * d**(i-j)

    return matrix

# %%
# Params
S = 80
T = 1
N = 2
vol = 0.2

# Call tree
buildTree(S, vol, T, N)
# Out:
# array([[ 80.        ,   0.        ,   0.        ],
#        [ 69.44987563,  92.15279281,   0.        ],
#        [ 60.29106532,  80.        , 106.15171529]])

# %%
def valueOption(stock_price, strike_price, option_type, position):
    """Values an option given a stock price, strike price, type of option either 'call' or 'put' and a position: 'long' or 'short'"""
    if option_type == 'call':
        # If call option, payoff equals
        pay_off = np.maximum(0, stock_price - strike_price)
    elif option_type == 'put':
        # If put option, payoff equals
        pay_off = np.maximum(0, strike_price - stock_price)
    # If the position is short, return minus pay off
    if position == 'short':
        return -1*pay_off
    # If the position is long, return pay off
    else:
        return pay_off

# %%
def Calculate_delta(u, d, S0, K, option_type='call', position = 'long'):
    """"Returns a delta calculated based on the option value in up state minus down state devided by the stock value in up state minus down state. 
    Takes parameters u, d, stock price S0, Strike price K, optio_type (set to call by default) and positon (set to long by default)
    Returns delta"""
    f_u = valueOption(stock_price= S0*u, strike_price= K, option_type=option_type, position=position)
    f_d = valueOption(stock_price= S0*d, strike_price= K, option_type=option_type, position=position)
    delta = (f_u - f_d)/(S0*u - S0*d)
    return delta

# %%
def BlackScholes(S0, St, K, r, T, t, vol, mode = 'call'):
    """"Returns option valuation according to the black and scholes method"""
    d1 = (np.log(St/K) + (r + vol**2/2)*(T-t))/vol*np.sqrt(T-t)
    d2 = d1 - vol*np.sqrt(T-t)
    if mode == 'call':
        option_price = S0*norm.cdf(d1) - K*np.exp(-r*T)*norm.cdf(d2)
    elif mode == 'put':
        option_price = K*np.exp(-r*T)*norm.cdf(-d2) - S0*norm.cdf(-d1)
    return option_price, d1, d2

# %%
def valueOptionMatrix(N, tree, T, r, K, vol, option_type= 'call', position = 'long'):
    dt = T / N
    u = np.exp(vol*np.sqrt(dt))
    d = np.exp(-vol*np.sqrt(dt))
    p = (np.exp(r*dt) - d)/(u - d)


    columns = tree.shape[1]
    rows = tree.shape[0]

    # Walk backward, we start in last row of the matrix

    if option_type == 'call':

    # Add the payoff function in the last row
        for c in np.arange(columns):
            S = tree[rows - 1, c] # value in the matrix
            tree[rows - 1, c] = valueOption(stock_price= S, strike_price=K, option_type=option_type, position = 'long')

        # For all other rows, we need to combine from previous rows
        # We walk backwards, from the last row to the first row
        for i in np.arange(rows - 1)[::-1]:
            for j in np.arange(i + 1):
                down = tree[i + 1, j]
                up = tree[i + 1, j + 1]
                tree[i, j] = np.exp(-r*dt) * (p*up + (1-p)*down)
    return tree

# %% [markdown]
# #### QUESTION 2.1

# %%
S0 = 80
σ = 0.2
T = 1
treeN = buildTree(S=S0, vol = 0.1, T = T, N = 2)

# %%
N = 50 
K = 99
r = 0.06
S0 = 100
σ = 0.2
T = 1
treeN = buildTree(S=S0, vol = σ, T = T, N = N)
optionMatrix = valueOptionMatrix(tree=treeN, T=T, r=r, K=K, vol=σ, option_type='call', position='long', N = N)
priceApproximately = optionMatrix[0,0] # This is our f0 at the root of the tree we want to calculate
print(f"Option value for the 50 step binomila tree is {priceApproximately}")
# Out:
# Option value for the 50 step binomila tree is 11.546434850755071

# %% [markdown]
# ### Question 2.3

# %%
# Play around with different ranges of N and step sizes.
K = 99
r = 0.06
S0 = 100
σ = 0.2
T = 1
N = np.arange(1,100)

approximatedPrices = []
    
# calculate option price for each n in N
for n in N:
    treeN = buildTree(S=S0, vol = σ, T = T, N = n)
    optionMatrix = valueOptionMatrix(tree=treeN, T=T, r=r, K=K, vol=σ, option_type='call', position='long', N = n)
    priceApproximately = optionMatrix[0,0] # This is our f0 at the root of the tree we want to calculate
    approximatedPrices.append(priceApproximately)

## Plotting convergence of option price as N increases
plt.figure(figsize=(10, 6))
plt.plot(N, approximatedPrices)
plt.xlabel("Number of Steps")
plt.ylabel("Approximatrd Option Price")
plt.grid(True)

# %% [markdown]
# ### Q. 2.4 Hedge Parameter

# %% [markdown]
# #### Question 2.2

# %%
# Option attributes from the assignment problem B 2.1
K = 99
r = 0.06
St = 100
T = 1
N_range = np.arange(1, 300)  # Range of N values

# Define multiple volatility levels to include in the plot
volatility_levels = [0.1, 0.2, 0.4]  # Example volatility levels

# Prepare the plot
plt.figure(figsize=(14, 6))

for vol in volatility_levels:
    # Calculate the option price for the correct parameters, selecting the 0th element as that is the option price
    optionPriceAnalytical = BlackScholes(S0=St, St=St, K=K, r=r, T=T, t=0, vol=vol)[0]

    approximatedPrices = []  # Reset the approximated prices list for the current volatility
    errors = []  # Reset the errors list for the current volatility

    # Calculate option price for each n in N_range
    for n in N_range:
        treeN = buildTree(S=St, vol=vol, T=T, N=n)
        optionMatrix = valueOptionMatrix(tree=treeN, T=T, r=r, K=K, vol=vol, option_type='call', position='long', N=n)
        priceApproximately = optionMatrix[0,0]  # This is our f0 at the root of the tree we want to calculate
        errors.append(abs(priceApproximately - optionPriceAnalytical))
        approximatedPrices.append(priceApproximately)

    # Plotting the prices
    plt.subplot(1, 2, 1)
    plt.plot(N_range, [optionPriceAnalytical]*len(N_range), label=f'BS Price, vol={vol}', linestyle='--')
    plt.plot(N_range, approximatedPrices, label=f'Binomial Price, vol={vol}')
    plt.xlabel('Number of Steps in Binomial Tree (N)')
    plt.ylabel('Option Price')
    plt.title('Option Pricing: Black-Scholes vs. Binomial Tree Model')
    plt.legend()
    plt.grid(True)

    # Plotting the errors
    plt.subplot(1, 2, 2)
    plt.plot(N_range, errors, label=f'Error, vol={vol}')
    plt.xlabel('Number of Steps in Binomial Tree (N)')
    plt.ylabel('Absolute Error')
    plt.title('Absolute Error in Option Pricing as N increases')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Question 2.5

# %%
def american_option_binomial_tree(S, K, r, T, sigma, option_type='call', steps=1000):
    dt = T / steps
    u = np.exp(sigma * np.sqrt(dt))
    d = 1 / u
    p = (np.exp(r * dt) - d) / (u - d)

    # Initialize stock price tree
    stock_price_tree = np.zeros((steps + 1, steps + 1))
    for i in range(steps + 1):
        for j in range(i + 1):
            stock_price_tree[j, i] = S * (u ** (j)) * (d ** (i  - j))

    # Initialize option value tree
    option_value_tree = np.zeros((steps + 1, steps + 1))
    if option_type == 'call':
        option_value_tree[:, steps] = np.maximum(0, stock_price_tree[:, steps] - K)
    elif option_type == 'put':
        option_value_tree[:, steps] = np.maximum(0, K - stock_price_tree[:, steps])

    # Calculate option prices at each node
    for i in range(steps - 1, -1, -1):
        for j in range(i + 1):
            if option_type == 'call':
                option_value_tree[j, i] = np.maximum(stock_price_tree[j, i] - K,
                                                      np.exp(-r * dt) * (p * option_value_tree[j, i + 1] +
                                                                         (1 - p) * option_value_tree[j + 1, i + 1]))
            elif option_type == 'put':
                option_value_tree[j, i] = np.maximum(K - stock_price_tree[j, i],
                                                      np.exp(-r * dt) * (p * option_value_tree[j, i + 1] +
                                                                         (1 - p) * option_value_tree[j + 1, i + 1]))

    return option_value_tree[0, 0]

# Example usage:
S = 100  # Current stock price
K = 100  # Strike price
r = 0.05  # Risk-free interest rate
T = 1.0  # Time to expiration (in years)
sigma = 0.2  # Volatility
option_type = 'call'  # 'call' or 'put'
steps = 50  # Number of steps in the binomial tree
K = 99
r = 0.06
S0 = 100
σ = 0.2
T = 1
N = np.arange(1,100)

american_option_price = american_option_binomial_tree(S, K, r, T, sigma, option_type, steps)
print("American option price:", american_option_price)
# Out:
# American option price: 7.289709909037612

# %% [markdown]
# ## Question 3.1

# %% [markdown]
# ## Question 3.2

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def blackScholes(current_stock_price, strike_price, current_time, maturity_time, interest_rate, volatality):
    
    tao = maturity_time - current_time
    d1 = (np.log(current_stock_price/strike_price) + (interest_rate + volatality**2/2) * tao)/(volatality*np.sqrt(tao))
    d2 = d1 - volatality * np.sqrt(tao)
    option_price = current_stock_price * norm.cdf(d1) - np.exp(-interest_rate * tao) * strike_price * norm.cdf(d2)
    
    return option_price, norm.cdf(d1)

# %%
blackScholes(49, 50, 0, .3846, 0.05, 0.2)
# Out:
# (2.4004610869656666, 0.5216016339715761)

# %% [markdown]
# ## Question 3.3

# %%
M = 365
T = 1.0
delta_t = T/M
S0 = 100
volatality = 0.2
interest_rate = 0.06

# %%
def exact_Method(S0, interest_rate, delta_t, M, volatality):
    final_stock = []
    for _ in range(1):
        prev_S = S0
        stock_prices = []
        for m in range(1, M+1):
            Zm = np.random.normal()
            next_S = prev_S * np.exp((interest_rate - (volatality)**2 / 2)* delta_t + volatality * np.sqrt(delta_t) * Zm)
            prev_S = next_S
            stock_prices.append(next_S)
        final_stock.append(np.array(stock_prices))
    return (np.mean(final_stock, axis=0))

# %%
def euler_Method(S0, interest_rate, delta_t, M, volatality):
    final_stock = []
    for _ in range(1):
        prev_S = S0
        stock_prices = [S0]
        for m in range(1, M):
            Zm = norm.rvs()
            next_S = prev_S * ( 1 + interest_rate * delta_t + volatality * np.sqrt(delta_t) * Zm )
            prev_S = next_S
            stock_prices.append(next_S)
        final_stock.append(np.array(stock_prices))
    return (np.mean(final_stock, axis=0))

# %%
time_values = np.array(list(range(1, M+1)))/M
E_stock_prices = euler_Method(S0, interest_rate, delta_t, M, 0.2)
exact_Sim = exact_Method(S0, interest_rate, delta_t, M, 0.2)

# %%
plt.plot(time_values, E_stock_prices, label="Euler")
plt.plot(time_values, exact_Sim, label="Exact")
plt.legend()

# %%
final_price = []
for _ in range(5000):
    E_stock_prices = euler_Method(S0, interest_rate, delta_t, M, volatality)
    final_price.append(E_stock_prices[-1])

# %%
plt.hist(final_price, bins=50, edgecolor='black')
# Out:
# (array([  1.,   0.,   1.,   3.,   5.,  12.,  48.,  47.,  73., 127., 176.,
#         205., 245., 270., 305., 289., 350., 318., 325., 308., 278., 228.,
#         225., 219., 180., 152., 119.,  98.,  63.,  61.,  50.,  42.,  47.,
#          39.,  25.,  16.,   7.,   9.,  13.,   5.,   3.,   6.,   2.,   2.,
#           0.,   1.,   1.,   0.,   0.,   1.]),
#  array([ 42.82611253,  46.2149873 ,  49.60386208,  52.99273686,
#          56.38161163,  59.77048641,  63.15936119,  66.54823596,
#          69.93711074,  73.32598552,  76.71486029,  80.10373507,
#          83.49260985,  86.88148462,  90.2703594 ,  93.65923418,
#          97.04810895, 100.43698373, 103.82585851, 107.21473328,
#         110.60360806, 113.99248284, 117.38135761, 120.77023239,
#         124.15910717, 127.54798194, 130.93685672, 134.3257315 ,
#         137.71460627, 141.10348105, 144.49235583, 147.8812306 ,
#         151.27010538, 154.65898016, 158.04785493, 161.43672971,
# ...

# %%
strike_price = 99
M = 365
T = 1.0
delta_t = T/M
S0 = 100
volatality = 0.2
interest_rate = 0.06

# %% [markdown]
# ### Daily Hedging

# %%
def calculate_Delta_Option(E_stock_prices, strike_price, T , interest_rate, volatality):
    deltas = []
    option_values = []
    time_values = np.array(list(range(1, M+1)))/M
    for i in range(len(time_values) - 1):
        option_value, delta = blackScholes(E_stock_prices[i], strike_price, time_values[i], T, interest_rate, volatality)
        option_values.append(option_value)
        deltas.append(delta)
    return option_values, deltas

# %%
total_cost = []
pay_received = []
for j in range(10000):
    prev_delta = 0
    cost = 0
    E_stock_prices = euler_Method(S0, interest_rate, delta_t, M, volatality)
    option_values, deltas = calculate_Delta_Option(E_stock_prices, strike_price, T , interest_rate, volatality)
    # Money of option at time of maturity
    money_option = option_values[0] * np.exp( interest_rate * T)   
    
    for i in range(len(deltas)):
        cost -= E_stock_prices[i] * (deltas[i] - prev_delta) * np.exp(interest_rate * (T - time_values[i]))
        prev_delta = deltas[i]
    if E_stock_prices[-1] > strike_price:
        cost -= E_stock_prices[-1] *  (1 - deltas[-1])
        money_received = money_option + strike_price
    else:
        cost += E_stock_prices[-1] *  (deltas[-1])
        money_received = money_option
    total_cost.append(cost)
    pay_received.append(money_received)
    #print(f"total cashflow {cashflow_from_selling_stock + cost + money_option}")

# %%
final_PnL_Daily = np.array(pay_received) + np.array(total_cost)
mean_PnL_Daily = np.mean(final_PnL_Daily)
PnL_Daily_5 = np.percentile(final_PnL_Daily, 5)
PnL_Daily_95 = np.percentile(final_PnL_Daily, 95)
PnL_Daily_var = np.var(final_PnL_Daily)

# %%
from scipy.stats import norm 
import statistics 
x_axis = np.arange(-2, 2, 0.001)        
mean = statistics.mean(final_PnL_Daily) 
sd = statistics.stdev(final_PnL_Daily) 
plt.plot(x_axis, norm.pdf(x_axis, mean, sd)) 
plt.show()

# %%
fig, ax = plt.subplots(dpi=300)
ax.hist(final_PnL_Daily, bins=50, edgecolor='black', alpha = 0.7)
ax.axvline(x = mean_PnL_Daily, color = "red", label = "Mean", linestyle = "--")
ax.axvline(x = PnL_Daily_5, color = "green", label = "5th percentile", linestyle = "--")
ax.axvline(x = PnL_Daily_95, color = "green", label = "95th percentile", linestyle = "--")
ax.plot(x_axis, norm.pdf(x_axis, mean, sd), color = "red") 
ax.set_xlabel('P&L')
ax.set_ylabel('Frequency')
ax.legend()
fig.savefig('cashflo_daily.png')

# %% [markdown]
# ### Weekly Hedging

# %%
total_cost_week = []
money_received_week = []

for j in range(10000):
    prev_delta = 0
    cost = 0
    
    E_stock_prices = euler_Method(S0, interest_rate, delta_t, M, volatality)
    option_values, deltas = calculate_Delta_Option(E_stock_prices, strike_price, T , interest_rate, volatality)
    
    # Money of option at time of maturity
    money_option = option_values[0] * np.exp(interest_rate * T)   
    
    for i in range(0, len(deltas), 8):
        cost -= E_stock_prices[i] * (deltas[i] - prev_delta) * np.exp( interest_rate * (T - time_values[i]))
        prev_delta = deltas[i]
    
    if E_stock_prices[-1] > strike_price:
        cost -= E_stock_prices[-1] *  (1 - deltas[-1])
        money_received = money_option + strike_price
    else:
        cost += E_stock_prices[-1] *  (deltas[-1])
        money_received = money_option
        
    total_cost_week.append(cost)
    money_received_week.append(money_received)

# %%
final_PnL_Weekly = np.array(total_cost_week) + np.array(money_received_week)
mean_PnL_Weekly = np.mean(final_PnL_Weekly)
PnL_Weekly_5 = np.percentile(final_PnL_Weekly, 5)
PnL_Weekly_95 = np.percentile(final_PnL_Weekly, 95)

# %%
fig, ax = plt.subplots(dpi=300)
ax.hist(final_PnL_Weekly, bins=50, edgecolor='black', alpha = 0.9)
ax.axvline(x = mean_PnL_Weekly, color = "red", label = "Mean", linestyle = "--")
ax.axvline(x = PnL_Weekly_5, color = "green", label = "5th percentile", linestyle = "--")
ax.axvline(x = PnL_Weekly_95, color = "green", label = "95th percentile", linestyle = "--")
ax.set_xlabel('P&L')
ax.set_ylabel('Simulation Number')
ax.legend()
fig.savefig('cashflo_weekly.png')

# %% [markdown]
# ### When volatility do not match

# %%
## volatality in stock price calculation is 0.2 and 0.3 in Delta Valuation
total_cost_vol = []
money_received_vol = []
for j in range(10000):
    prev_delta = 0
    cost = 0
    ##Generating Stock Prices for one year using Euler Methode  and volatality 0.2
    E_stock_prices = euler_Method(S0, interest_rate, delta_t, M, 0.2)
    ##Generating Delta for Daily in one year of period using Black-Scholes Method and volatality 0.3
    option_values, deltas = calculate_Delta_Option(E_stock_prices, strike_price, T , interest_rate, 0.3)
    
    # Money received from selling an option at time of maturity
    money_option = option_values[0] * np.exp( interest_rate * T) 
    
    ## Calculating the cost of delta hedging
    for i in range(0, len(deltas)):
        cost -= E_stock_prices[i] * (deltas[i] - prev_delta) * np.exp( interest_rate * (T - time_values[i]))
        prev_delta = deltas[i]

    ## Check whether stock price is greater than strike price or not at the end of the period
    if E_stock_prices[-1] > strike_price:
        cost -= E_stock_prices[-1] *  (1 - deltas[-1])
        money_received = money_option + strike_price
    else:
        cost += E_stock_prices[-1] *  (deltas[-1])
        money_received = money_option
    
    #Appending the total cost of delta hedging for each simulation
    total_cost_vol.append(cost)
    money_received_vol.append(money_received)

# %%
final_PnL_HVol = np.array(total_cost_vol) + np.array(money_received_vol)
mean_PnL_HVol = np.mean(final_PnL_HVol)
PnL_HVol_5 = np.percentile(final_PnL_HVol, 5)
PnL_HVol_95 = np.percentile(final_PnL_HVol, 95)

# %%
## volatality in stock price calculation is 0.2 and 0.3 in Delta Valuation
total_cost_vol2 = []
money_received_vol2 = []
for j in range(10000):
    prev_delta = 0
    cost = 0
    ##Generating Stock Prices for one year using Euler Methode  and volatality 0.3
    E_stock_prices = euler_Method(S0, interest_rate, delta_t, M, 0.2)
    ##Generating Delta for Daily in one year of period using Black-Scholes Method and volatality 0.2
    option_values, deltas = calculate_Delta_Option(E_stock_prices, strike_price, T , interest_rate, 0.1)
    
    # Money received from selling an option at time of maturity
    money_option = option_values[0] * np.exp( interest_rate * T)
    
    ## Calculating the cost of delta hedging
    for i in range(0, len(deltas)):
        cost -= E_stock_prices[i] * (deltas[i] - prev_delta) * np.exp( interest_rate * (T - time_values[i]))
        prev_delta = deltas[i]

    ## Check whether stock price is greater than strike price or not at the end of the period
    if E_stock_prices[-1] > strike_price:
        cost -= E_stock_prices[-1] *  (1 - deltas[-1])
        money_received = money_option + strike_price
    else:
        cost += E_stock_prices[-1] *  (deltas[-1])
        money_received = money_option
    
    #Appending the total cost of delta hedging for each simulation
    total_cost_vol2.append(cost)
    money_received_vol2.append(money_received)

# %%
final_PnL_LVol = np.array(total_cost_vol2) + np.array(money_received_vol2)
mean_PnL_LVol = np.mean(final_PnL_LVol)
PnL_LVol_5 = np.percentile(final_PnL_LVol, 5)
PnL_LVol_95 = np.percentile(final_PnL_LVol, 95)

# %%
fig, ax = plt.subplots(dpi=300)
ax.hist(final_PnL_HVol,bins=50, label='Higher Volatility', edgecolor='black', alpha = 0.7)
ax.hist(final_PnL_LVol, bins=50, label='Lower Volatility', edgecolor='black', alpha = 0.7)
ax.axvline(x = mean_PnL_LVol, color = "red", label = "Mean", linestyle = "--")
ax.axvline(x = PnL_LVol_5, color = "green", label = "5th percentile", linestyle = "--")
ax.axvline(x = PnL_LVol_95, color = "green", label = "95th percentile", linestyle = "--")
ax.axvline(x = mean_PnL_HVol, color = "red", linestyle = "--")
ax.axvline(x = PnL_HVol_5, color = "green", linestyle = "--")
ax.axvline(x = PnL_HVol_95, color = "green", linestyle = "--")
ax.set_xlabel('P&L')
ax.set_ylabel('Density')
ax.legend()
fig.savefig('cashflow_Vol_Daily.png')

# %% [markdown]
# ## Different Volatility in Weekly Hedging

# %%
## volatality in stock price calculation is 0.2 and 0.3 in Delta Valuation
total_cost_vol_W = []
money_received_vol_W = []
for j in range(10000):
    prev_delta = 0
    cost = 0
    ##Generating Stock Prices for one year using Euler Methode  and volatality 0.2
    E_stock_prices = euler_Method(S0, interest_rate, delta_t, M, 0.2)
    ##Generating Delta for Daily in one year of period using Black-Scholes Method and volatality 0.3
    option_values, deltas = calculate_Delta_Option(E_stock_prices, strike_price, T , interest_rate, 0.3)
    
    # Money received from selling an option at time of maturity
    money_option = option_values[0] * np.exp( interest_rate * T) 
    
    ## Calculating the cost of delta hedging
    for i in range(0, len(deltas), 8):
        cost -= E_stock_prices[i] * (deltas[i] - prev_delta) * np.exp( interest_rate * (T - time_values[i]))
        prev_delta = deltas[i]

    ## Check whether stock price is greater than strike price or not at the end of the period
    if E_stock_prices[-1] > strike_price:
        cost -= E_stock_prices[-1] *  (1 - deltas[-1])
        money_received = money_option + strike_price
    else:
        cost += E_stock_prices[-1] *  (deltas[-1])
        money_received = money_option
    
    #Appending the total cost of delta hedging for each simulation
    total_cost_vol_W.append(cost)
    money_received_vol_W.append(money_received)

# %%
final_PnL_HVol_W = np.array(total_cost_vol_W) + np.array(money_received_vol_W)
mean_PnL_HVol_W = np.mean(final_PnL_HVol_W)
PnL_HVol_5_W = np.percentile(final_PnL_HVol_W, 5)
PnL_HVol_95_W = np.percentile(final_PnL_HVol_W, 95)

# %%
fig, ax = plt.subplots(dpi=300)
ax.hist(final_PnL_HVol_W,bins=50, edgecolor='black', label='Higher Volatility')
ax.axvline(x = PnL_HVol_5_W, color = "green", linestyle = "--",  label = "95th percentile")
ax.axvline(x = PnL_HVol_95_W, color = "green", linestyle = "--", label = "5th percentile")
ax.axvline(x = mean_PnL_HVol_W, color = "red", linestyle = "--", label = "Mean")
ax.set_xlabel('P&L')
ax.set_ylabel('Simulation Number')
ax.legend()
fig.savefig('cashflow_HVol_Weekly.png')

# %%
## volatality in stock price calculation is 0.2 and 0.3 in Delta Valuation
total_cost_vol2_W = []
money_received_vol2_W = []
for j in range(10000):
    prev_delta = 0
    cost = 0
    ##Generating Stock Prices for one year using Euler Methode  and volatality 0.3
    E_stock_prices = euler_Method(S0, interest_rate, delta_t, M, 0.2)
    ##Generating Delta for Daily in one year of period using Black-Scholes Method and volatality 0.2
    option_values, deltas = calculate_Delta_Option(E_stock_prices, strike_price, T , interest_rate, 0.1)
    
    # Money received from selling an option at time of maturity
    money_option = option_values[0] * np.exp( interest_rate * T)
    
    ## Calculating the cost of delta hedging
    for i in range(0, len(deltas), 8):
        cost -= E_stock_prices[i] * (deltas[i] - prev_delta) * np.exp( interest_rate * (T - time_values[i]))
        prev_delta = deltas[i]

    ## Check whether stock price is greater than strike price or not at the end of the period
    if E_stock_prices[-1] > strike_price:
        cost -= E_stock_prices[-1] *  (1 - deltas[-1])
        money_received = money_option + strike_price
    else:
        cost += E_stock_prices[-1] *  (deltas[-1])
        money_received = money_option
    
    #Appending the total cost of delta hedging for each simulation
    total_cost_vol2_W.append(cost)
    money_received_vol2_W.append(money_received)

# %%
final_PnL_LVol_W = np.array(total_cost_vol2_W) + np.array(money_received_vol2_W)
mean_PnL_LVol_W = np.mean(final_PnL_LVol_W)
PnL_LVol_5_W = np.percentile(final_PnL_LVol_W, 5)
PnL_LVol_95_W = np.percentile(final_PnL_LVol_W, 95)

# %%
fig, ax = plt.subplots(dpi=300)
ax.hist(final_PnL_LVol_W, bins=50, edgecolor='black', label='Lower Volatility')
ax.axvline(x = mean_PnL_LVol_W, color = "red", label = "Mean", linestyle = "--")
ax.axvline(x = PnL_LVol_5_W, color = "green", label = "5th percentile", linestyle = "--")
ax.axvline(x = PnL_LVol_95_W, color = "green", label = "95th percentile", linestyle = "--")
ax.set_xlabel('P&L')
ax.set_ylabel('Total Cashflow')
ax.legend()
fig.savefig('cashflow_LVol_Weekly.png')
